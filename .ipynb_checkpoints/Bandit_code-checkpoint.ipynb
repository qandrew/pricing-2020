# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt

# DP Formula
# V[x] = max(0, [xp + (1-x)q] V(x_win) + [x(1-p) + (1-x)(1-q)] V(x_lose) + [xp + (1-x)q] - c ))

# %%
roundfactor = 2

def update_prior(x,p,q,c,result):
    if result == True:
        out = p*x/(win(x,p,q))
    else:
        out = (1 - p)*x/(lose(x,p,q))
    return round(out,roundfactor)

def expected_outcome(x,p,q,c):
    out = win(x,p,q) - c
    return round(out,roundfactor)

def win(x,p,q):
    return x*p + (1-x)*q

def lose(x,p,q):
    return x*(1-p) + (1-x)*(1-q)

def get_recursive_value(x,p,q,c,V):
    pass

# %%
def split_recurrence_single(x,p,q,c, delta, high, low, V_dict, Sym_dict, debug = False):
    if debug:
        print("---at", x)
    
    # need to check for rounding error
    for i in range(-3,4,1):
        if x + i/10000 in Sym_dict:
            x = x + i/10000
            break
    
    if x in V_dict:
        return V_dict[x], V_dict, Sym_dict
    if x in Sym_dict:
        return Sym_dict[x], V_dict, Sym_dict
    elif x < low:
        V_dict[x] = 0
        temp = Symbol("var" + str(x))
        Sym_dict[x] = temp
        return 0, V_dict, Sym_dict
    elif x > high:
        V_dict[x] = round(expected_outcome(1,p,q,c)/(1 - delta), 4)
        temp = Symbol("var" + str(x))
        Sym_dict[x] = temp
        return V_dict[x], V_dict, Sym_dict
    else:
        temp = Symbol("var" + str(x))
        Sym_dict[x] = temp
        
        c_0 = expected_outcome(x,p,q,c)
        
        p_w = win(x,p,q)
        x_w = update_prior(x,p,q,c,True)
        
        p_l = lose(x,p,q)
        x_l = update_prior(x,p,q,c,False)
        
        s_1, V_dict, Sym_dict = split_recurrence_single(x_w,p,q,c,delta,high,low,V_dict,Sym_dict)
        s_2, V_dict, Sym_dict = split_recurrence_single(x_l,p,q,c,delta,high,low,V_dict,Sym_dict)
        
        out = delta*p_w*s_1 + delta*p_l*s_2 + c_0 # V[x] formula
        
        V_dict[x] = out
        return out, V_dict, Sym_dict
    
def solve_split_recurrence(x,p,q,c,delta,high,low, debug = False):
    V_dict = {}
    Sym_dict = {}
    val, V_dict, Sym_dict = split_recurrence_single(x,p,q,c,delta,high,low, V_dict, Sym_dict)
    
    if debug:
        print('---HELLO---')
        print("max possible value", round(expected_outcome(1,p,q,c)/(1 - delta), 4))

    t_dict = {}
    for k in V_dict:
        if debug:
            print(k,V_dict[k])
        if k in Sym_dict:
            t_dict[k] = V_dict[k] - Sym_dict[k]

    ans = solve(tuple(t_dict.values()), tuple(Sym_dict.values()))

    x_plot = []
    y_plot = []
    
    if debug: print('---sol---')

    for k,v in ans.items():
        if debug: print(k,v)
        if v < 0: print("WARNING v < 0",k,v)
        y_plot.append(v)
        x_plot.append(float(str(k)[3:]))
    
    return x_plot, y_plot

# %%
x_tot = []
y_tot = []
high, low = 0.99, 0.34

delta = 0.9 # discount rate
x = 0.5
p = 0.6
q = 0.4
c = 0.5
debug = False # set true to see equations


for x_temp in [0.5, 0.51, 0.62, 0.53, 0.64, 0.55, 0.66, 0.57, 0.68, 0.59]:
    x_plot, y_plot = solve_split_recurrence(x_temp, p,q,c,delta,high,low, debug)
    x_tot += x_plot
    y_tot += y_plot
    
min_x = 1
for i in range(len(x_tot)):
    if y_tot[i] > 0 and x_tot[i] < min_x:
        min_x = x_tot[i]

print("min x is", min_x)

x_tot = sorted(x_tot)
y_tot = sorted(y_tot)

plt.plot(x_tot, y_tot,'r')
plt.xlabel('x')
plt.ylabel('V(x)')
plt.axvline(x=low)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-bc079e26fe25> in <module>
#      12
#      13 for x_temp in [0.5, 0.51, 0.62, 0.53, 0.64, 0.55, 0.66, 0.57, 0.68, 0.59]:
# ---> 14     x_plot, y_plot = solve_split_recurrence(x_temp, p,q,c,delta,high,low, debug)
#      15     x_tot += x_plot
#      16     y_tot += y_plot
#
# <ipython-input-18-55ff46663f89> in solve_split_recurrence(x, p, q, c, delta, high, low, debug)
#      59             t_dict[k] = V_dict[k] - Sym_dict[k]
#      60
# ---> 61     ans = solve(tuple(t_dict.values()), tuple(Sym_dict.values()))
#      62
#      63     x_plot = []
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1148             if fi.has(Float):
#    1149                 floats = True
# -> 1150                 f[i] = nsimplify(fi, rational=True)
#    1151
#    1152     # capture any denominators before rewriting since
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/simplify/simplify.py in nsimplify(expr, constants, tolerance, full, rational, rational_conversion)
#    1308         return expr
#    1309     if rational or expr.free_symbols:
# -> 1310         return _real_to_rational(expr, tolerance, rational_conversion)
#    1311
#    1312     # SymPy's default tolerance for Rationals is 15; other numbers may have
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/simplify/simplify.py in _real_to_rational(expr, tolerance, rational_conversion)
#    1428                 raise ValueError("rational_conversion must be 'base10' or 'exact'")
#    1429
# -> 1430             r = nsimplify(fl, rational=False)
#    1431             # e.g. log(3).n() -> log(3) instead of a Rational
#    1432             if fl and not r:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/simplify/simplify.py in nsimplify(expr, constants, tolerance, full, rational, rational_conversion)
#    1366     try:
#    1367         if re:
# -> 1368             re = nsimplify_real(re)
#    1369         if im:
#    1370             im = nsimplify_real(im)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/simplify/simplify.py in nsimplify_real(x)
#    1349             mpmath.mp.dps = prec
#    1350             newexpr = mpmath.identify(xv, constants=constants_dict,
# -> 1351                 tol=tolerance, full=full)
#    1352             if not newexpr:
#    1353                 raise ValueError
#
# ~/anaconda3/lib/python3.6/site-packages/mpmath/identification.py in identify(ctx, x, constants, tol, maxcoeff, full, verbose)
#     826                 logs.append((ctx.ln(a), s))
#     827         logs = [(ctx.ln(i),str(i)) for i in ilogs] + logs
# --> 828         r = ctx.pslq([ctx.ln(x)] + [a[0] for a in logs], tol, M)
#     829         if r is not None and max(abs(uw) for uw in r) <= M and r[0]:
#     830             addsolution(prodstring(r, logs))
#
# ~/anaconda3/lib/python3.6/site-packages/mpmath/identification.py in pslq(ctx, x, tol, maxcoeff, maxsteps, verbose)
#     261             for j in xrange(min(i-1, m+1), 0, -1):
#     262                 try:
# --> 263                     t = round_fixed((H[i,j] << prec)//H[j,j], prec)
#     264                 # Precision probably exhausted
#     265                 except ZeroDivisionError:
#
# ~/anaconda3/lib/python3.6/site-packages/mpmath/identification.py in round_fixed(x, prec)
#       9 # round to nearest integer (can be done more elegantly...)
#      10 def round_fixed(x, prec):
# ---> 11     return ((x + (1<<(prec-1))) >> prec) << prec
#      12
#      13 class IdentificationMethods(object):
#
# KeyboardInterrupt:

# %%
x_tot = []
y_tot = []
high, low = 0.99, 0.34

delta = 0.9 # discount rate
x = 0.5
p = 0.7
q = 0.4
c = 0.5
debug = False # set true to see equations


# for x_temp in [0.5, 0.51, 0.62, 0.53, 0.64, 0.55, 0.66, 0.57, 0.68, 0.59]:
x_plot, y_plot = solve_split_recurrence(0.5, p,q,c,delta,high,low, debug)
x_tot += x_plot
y_tot += y_plot
    
min_x = 1
for i in range(len(x_tot)):
    if y_tot[i] > 0 and x_tot[i] < min_x:
        min_x = x_tot[i]

print("min x is", min_x)

plt.plot(x_tot, y_tot, 'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-abbb37af5c21> in <module>
#      12
#      13 # for x_temp in [0.5, 0.51, 0.62, 0.53, 0.64, 0.55, 0.66, 0.57, 0.68, 0.59]:
# ---> 14 x_plot, y_plot = solve_split_recurrence(0.5, p,q,c,delta,high,low, debug)
#      15 x_tot += x_plot
#      16 y_tot += y_plot
#
# <ipython-input-18-55ff46663f89> in solve_split_recurrence(x, p, q, c, delta, high, low, debug)
#      59             t_dict[k] = V_dict[k] - Sym_dict[k]
#      60
# ---> 61     ans = solve(tuple(t_dict.values()), tuple(Sym_dict.values()))
#      62
#      63     x_plot = []
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1171         solution = _solve(f[0], *symbols, **flags)
#    1172     else:
# -> 1173         solution = _solve_system(f, symbols, **flags)
#    1174
#    1175     #
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1809                 result = minsolve_linear_system(matrix, *symbols, **flags)
#    1810             else:
# -> 1811                 result = solve_linear_system(matrix, *symbols, **flags)
#    1812             if failed:
#    1813                 if result:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in solve_linear_system(system, *symbols, **flags)
#    2271         try:
#    2272             # well behaved n-equations and n-unknowns
# -> 2273             inv = inv_quick(system[:, :-1])
#    2274             rv = dict(zip(symbols, inv*system[:, -1]))
#    2275             if do_simplify:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/solvers/solvers.py in inv_quick(M)
#    2578             det = lambda _: det_minor(_)
#    2579     else:
# -> 2580         return M.inv()
#    2581     n = M.rows
#    2582     d = det(M)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in inv(self, method, **kwargs)
#    3192         if method is not None:
#    3193             kwargs['method'] = method
# -> 3194         return self._eval_inverse(**kwargs)
#    3195
#    3196     def is_nilpotent(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/dense.py in _eval_inverse(self, **kwargs)
#     267         M = self.as_mutable()
#     268         if method == "GE":
# --> 269             rv = M.inverse_GE(iszerofunc=iszerofunc)
#     270         elif method == "LU":
#     271             rv = M.inverse_LU(iszerofunc=iszerofunc)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in inverse_GE(self, iszerofunc)
#    3105
#    3106         big = Matrix.hstack(self.as_mutable(), Matrix.eye(self.rows))
# -> 3107         red = big.rref(iszerofunc=iszerofunc, simplify=True)[0]
#    3108         if any(iszerofunc(red[j, j]) for j in range(red.rows)):
#    3109             raise ValueError("Matrix det == 0; not invertible.")
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in rref(self, iszerofunc, simplify, pivots, normalize_last)
#     934         ret, pivot_cols = self._eval_rref(iszerofunc=iszerofunc,
#     935                                           simpfunc=simpfunc,
# --> 936                                           normalize_last=normalize_last)
#     937         if pivots:
#     938             ret = (ret, pivot_cols)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in _eval_rref(self, iszerofunc, simpfunc, normalize_last)
#     589         reduced, pivot_cols, swaps = self._row_reduce(iszerofunc, simpfunc,
#     590                                                       normalize_last, normalize=True,
# --> 591                                                       zero_above=True)
#     592         return reduced, pivot_cols
#     593
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in _row_reduce(self, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     745                     continue
#     746
# --> 747                 cross_cancel(pivot_val, row, val, piv_row)
#     748             piv_row += 1
#     749
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/matrices/matrices.py in cross_cancel(a, i, b, j)
#     696             q = (j - i)*cols
#     697             for p in range(i*cols, (i + 1)*cols):
# --> 698                 mat[p] = a*mat[p] - b*mat[p + q]
#     699
#     700         piv_row, piv_col = 0, 0
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/numbers.py in __mul__(self, other)
#    2041                 return Integer(self.p*other)
#    2042             elif isinstance(other, Integer):
# -> 2043                 return Integer(self.p*other.p)
#    2044             elif isinstance(other, Rational):
#    2045                 return Rational(self.p*other.p, other.q, igcd(self.p, other.q))
#
# KeyboardInterrupt:
